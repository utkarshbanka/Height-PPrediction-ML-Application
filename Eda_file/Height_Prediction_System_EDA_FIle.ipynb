# %% [markdown]
# # Import Necessry Library --

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.metrics import r2_score

# %% [markdown]
# # Dataset --

# %%
# Features = [weight, age, shoe_size, arm_length, leg_length]
data = {
"weight": [60, 72, 80, 90, 100, 65, 78, 85, 95, 70],
"age": [25, 30, 28, 35, 40, 22, 27, 32, 38, 26],
"shoe_size": [8, 9, 10, 11, 12, 8, 9, 10, 11, 9],
"arm_length": [60, 65, 68, 70, 72, 61, 66, 69, 71, 64],
"leg_length": [90, 95, 98, 102, 105, 91, 96, 100, 104, 93],
"height": [170, 178, 182, 188, 193, 172, 180, 185, 190, 175]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    weight  age  shoe_size  arm_length  leg_length  height
# 0      60   25          8          60          90     170
# 1      72   30          9          65          95     178
# 2      80   28         10          68          98     182
# 3      90   35         11          70         102     188
# 4     100   40         12          72         105     193
# 5      65   22          8          61          91     172
# 6      78   27          9          66          96     180
# 7      85   32         10          69         100     185
# 8      95   38         11          71         104     190
# 9      70   26          9          64          93     175

# %%
df.describe()
# Out:
#            weight        age  shoe_size  arm_length  leg_length      height
# count   10.000000  10.000000  10.000000   10.000000   10.000000   10.000000
# mean    79.500000  30.300000   9.700000   66.600000   97.400000  181.300000
# std     13.083068   5.869885   1.337494    4.115013    5.295701    7.732328
# min     60.000000  22.000000   8.000000   60.000000   90.000000  170.000000
# 25%     70.500000  26.250000   9.000000   64.250000   93.500000  175.750000
# 50%     79.000000  29.000000   9.500000   67.000000   97.000000  181.000000
# 75%     88.750000  34.250000  10.750000   69.750000  101.500000  187.250000
# max    100.000000  40.000000  12.000000   72.000000  105.000000  193.000000

# %%
df.corr()
# Out:
#               weight       age  shoe_size  arm_length  leg_length    height
# weight      1.000000  0.936824   0.974686    0.982389    0.994297  0.996746
# age         0.936824  1.000000   0.946809    0.911717    0.950078  0.945186
# shoe_size   0.974686  0.946809   1.000000    0.964989    0.975737  0.976606
# arm_length  0.982389  0.911717   0.964989    1.000000    0.987116  0.988938
# leg_length  0.994297  0.950078   0.975737    0.987116    1.000000  0.998012
# height      0.996746  0.945186   0.976606    0.988938    0.998012  1.000000

# %%
plt.figure(figsize=(16,4))
sns.heatmap(df.corr(),annot=True)
plt.savefig('Coorelation_Heat_Map')

# %%
sns.pairplot(df,hue = 'height')

# %%
sns.scatterplot(data = df , 
               x = 'weight',
               y = 'height',hue = 'height')
# Out:
# <Axes: xlabel='weight', ylabel='height'>

# %%
sns.scatterplot(data = df , 
               x = 'age',
               y = 'height')
# Out:
# <Axes: xlabel='age', ylabel='height'>

# %%
sns.scatterplot(data = df , 
               x = 'shoe_size',
               y = 'height')
# Out:
# <Axes: xlabel='shoe_size', ylabel='height'>

# %%
sns.scatterplot(data = df , 
               x = 'arm_length',
               y = 'height')
# Out:
# <Axes: xlabel='arm_length', ylabel='height'>

# %%
sns.scatterplot(data = df , 
               x = 'leg_length',
               y = 'height')
# Out:
# <Axes: xlabel='leg_length', ylabel='height'>
